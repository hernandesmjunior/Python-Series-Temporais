# %% [markdown]
# # MÉDIA MÓVEL EM SÉRIES TEMPORAIS

# %% [markdown]
# # 0.0 Importações

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib.pylab import rcParams

sns.set()

# %%
rcParams['figure.figsize'] = 18,8

# %% [markdown]
# # 1.0 Temperatura Global
#
# Desvios da temperatura média global da terra-oceano (com referência a média de 1951-1980), medidos em graus Celsius, para os anos de 1880-2015.

# %%
temperatura = pd.read_csv('Data/temp_global.csv')
temperatura
# Out:
#         x
# 1   -0.20
# 2   -0.11
# 3   -0.10
# 4   -0.20
# 5   -0.28
# ..    ...
# 132  0.60
# 133  0.63
# 134  0.66
# 135  0.75
# 136  0.87
#
# [136 rows x 1 columns]

# %%
indice = pd.date_range('1880 Jan 1', periods=len(temperatura), freq='Y')

# %%
serie = pd.Series(temperatura['x'].values, index=indice)
serie
# Out:
# 1880-12-31   -0.20
# 1881-12-31   -0.11
# 1882-12-31   -0.10
# 1883-12-31   -0.20
# 1884-12-31   -0.28
#               ...
# 2011-12-31    0.60
# 2012-12-31    0.63
# 2013-12-31    0.66
# 2014-12-31    0.75
# 2015-12-31    0.87
# Freq: A-DEC, Length: 136, dtype: float64

# %%
serie.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 1.1 Cálculo da Média Móvel

# %%
media_movel1 = serie.rolling(window=3)
media_movel1 = media_movel1.mean()

# %%
plt.plot(media_movel1)

# %%
plt.plot(serie, label='Série Real')
plt.plot(media_movel1, color='red', label='Média Móvel 3 anos')
plt.legend(loc='upper left')
plt.title('VARIAÇÃO DA TEMPERATURA GLOBAL', fontweight='bold', fontsize=16)
plt.show()

# %%
media_movel2 = serie.rolling(window=10)
media_movel2 = media_movel2.mean()

plt.plot(serie, label='Série Real')
plt.plot(media_movel2, color='red', label='Média Móvel 10 anos')
plt.legend(loc='upper left')
plt.title('VARIAÇÃO DA TEMPERATURA GLOBAL', fontweight='bold', fontsize=16)
plt.show()

# %%
media_movel3 = serie.rolling(window=3, center=True)
media_movel3 = media_movel3.mean()

plt.plot(serie, label='Série Real')
plt.plot(media_movel3, color='red', label='Média Móvel Centralizada 3 anos')
plt.legend(loc='upper left')
plt.title('TEMPERATURA GLOBAL', fontweight='bold', fontsize=16)
plt.show()
